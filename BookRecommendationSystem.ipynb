# %%
import pandas as pd
import numpy as np

# %%
books_df = pd.read_csv('E:/DataScienceInternship/Project/book Recomendation data/RatingandUsersandBooksIn.csv')
books_df.head()
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_12380\4021238151.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv('E:/DataScienceInternship/Project/book Recomendation data/RatingandUsersandBooksIn.csv')
#    UserID        ISBN  Book-Rating                           Location   Age  \
# 0  276725  034545104X            0                  tyler, texas, usa   NaN
# 1    2313  034545104X            5              cincinnati, ohio, usa  23.0
# 2    6543  034545104X            0           strafford, missouri, usa  34.0
# 3    8680  034545104X            5  st. charles county, missouri, usa   2.0
# 4   10314  034545104X            9             beaverton, oregon, usa   NaN
#
#              Book-Title Book-Author Year-Of-Publication         Publisher  \
# 0  Flesh Tones: A Novel  M. J. Rose                2002  Ballantine Books
# 1  Flesh Tones: A Novel  M. J. Rose                2002  Ballantine Books
# ...

# %%
books_df.shape
# Out:
# (179091, 12)

# %%
print(len(books_df['Book-Title'].unique()))
books_df['Book-Title'].value_counts()
# Out:
# 64753
# A Painted House                                                     761
# Snow Falling on Cedars                                              565
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))    519
# The Firm                                                            493
# The No. 1 Ladies' Detective Agency (Today Show Book Club #8)        390
#                                                                    ...
# James Thurber: Writings and Drawings (Library of America)             1
# Fools Rush In (Harlequin Temptation No. 439)                          1
# Unforgettable Night (Rose Tattoo) (Intrigue , No 477)                 1
# Sonne, Mond und Luftballon                                            1
# Glamorous Movie Stars of the Thirties: Paper Dolls                    1
# Name: Book-Title, Length: 64753, dtype: int64

# %%
books_df.sort_values('UserID')
# Out:
#        UserID        ISBN  Book-Rating                  Location   Age  \
# 23636       8  1881320189            7  timmins, ontario, canada   NaN
# 23633       8  1575663937            6  timmins, ontario, canada   NaN
# 23632       8  1567407781            6  timmins, ontario, canada   NaN
# 23626       8  1558746218            0  timmins, ontario, canada   NaN
# 23625       8  1552041778            5  timmins, ontario, canada   NaN
# ...       ...         ...          ...                       ...   ...
# 23620  278851  1569661057           10        dallas, texas, usa  33.0
# 23538  278851  1558531025            8        dallas, texas, usa  33.0
# 23534  278851  020148837X            0        dallas, texas, usa  33.0
# 23537  278851  067161746X            7        dallas, texas, usa  33.0
# 9211   278854  042516098X            7     portland, oregon, usa   NaN
#
#                                               Book-Title  \
# ...

# %%
len(books_df.UserID.unique())
# Out:
# 34821

# %%
books_df['Book-Rating'].describe()
# Out:
# count    179091.000000
# mean          3.127901
# std           3.926865
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           7.000000
# max          10.000000
# Name: Book-Rating, dtype: float64

# %%
print(books_df.memory_usage(deep=True))
# Out:
# Index                       128
# UserID                  1432728
# ISBN                   11999109
# Book-Rating             1432728
# Location               15057064
# Age                     1432728
# Book-Title             17239028
# Book-Author            12766091
# Year-Of-Publication     7630244
# Publisher              12939846
# Image-URL-S            20953647
# Image-URL-M            20953647
# Image-URL-L            20953392
# dtype: int64
